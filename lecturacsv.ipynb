# %%
import pandas as pd

# %%
df = pd.read_csv('ModalidadVirtual.csv')

# %%
df
# Out:
#      Unnamed: 0        time                       carrera acepta  \
# 0             0  2020-11-08        Ingeniería de Sistemas     Si
# 1             1  2020-11-08                    Psicología     Si
# 2             2  2020-11-08        Ingeniería de Sistemas     Si
# 3             3  2020-11-08        Ingeniería de Sistemas     Si
# 4             4  2020-11-08        Ingeniería de Sistemas     Si
# ..          ...         ...                           ...    ...
# 217         230  2020-12-10  Gestión Turística y Hotelera     Si
# 218         231  2020-12-11        Ingeniería de Sistemas     No
# 219         232  2020-12-11  Gestión Turística y Hotelera     No
# 220         233  2020-12-11         Ingeniería Agronómica     Si
# 221         234  2020-12-12        Comercio Internacional     Si
#
#                           positivo  \
# 0                Horario flexible.
# 1    Acceso desde cualquier lugar.
# 2                Horario flexible.
# 3                Horario flexible.
# ...

# %%
df['carrera'][1]
# Out:
# 'Psicología'

# %%
df['edad'] > 23
# Out:
# 0      False
# 1       True
# 2      False
# 3      False
# 4       True
#        ...
# 217    False
# 218    False
# 219     True
# 220    False
# 221    False
# Name: edad, Length: 222, dtype: bool

# %%
filtrar = df['edad'] > 30
filtrar2 = df['carrera'] == 'Psicologia'

# %%
df_filtrar = df[(filtrar2) & (filtrar)]

# %%
df_filtrar
# Out:
#      Unnamed: 0        time     carrera acepta                       positivo  \
# 4             4  2020-11-08  Psicologia     Si  Acceso desde cualquier lugar.
# 10           10  2020-11-08  Psicologia     Si              Horario flexible.
# 18           20  2020-11-09  Psicologia     Si  Acceso desde cualquier lugar.
# 22           24  2020-11-09  Psicologia     Si  Acceso desde cualquier lugar.
# 23           25  2020-11-09  Psicologia     Si  Acceso desde cualquier lugar.
# ..          ...         ...         ...    ...                            ...
# 206         218  2020-12-08  Psicologia     Si              Horario flexible.
# 207         219  2020-12-08  Psicologia     Si  Acceso desde cualquier lugar.
# 208         220  2020-12-08  Psicologia     Si  Acceso desde cualquier lugar.
# 211         223  2020-12-08  Psicologia     Si  Acceso desde cualquier lugar.
# 212         224  2020-12-08  Psicologia     Si  Acceso desde cualquier lugar.
#
# ...

# %%
df.head(10)
# Out:
#    Unnamed: 0        time                   carrera acepta  \
# 0           0  2020-11-08    Ingeniería de Sistemas     Si
# 1           1  2020-11-08                Psicología     Si
# 2           2  2020-11-08    Ingeniería de Sistemas     Si
# 3           3  2020-11-08    Ingeniería de Sistemas     Si
# 4           4  2020-11-08    Ingeniería de Sistemas     Si
# 5           5  2020-11-08  Ciencias de la Educación     Si
# 6           6  2020-11-08    Ingeniería de Sistemas     Si
# 7           7  2020-11-08    Ingeniería de Sistemas     Si
# 8           8  2020-11-08    Ingeniería de Sistemas     Si
# 9           9  2020-11-08    Ingeniería de Sistemas     Si
#
#                         positivo  \
# 0              Horario flexible.
# 1  Acceso desde cualquier lugar.
# 2              Horario flexible.
# 3              Horario flexible.
# 4  Acceso desde cualquier lugar.
# 5  Acceso desde cualquier lugar.
# 6  Acceso desde cualquier lugar.
# 7              Horario flexible.
# ...
